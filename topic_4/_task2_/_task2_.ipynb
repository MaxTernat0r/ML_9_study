# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import matplotlib.pyplot as plt
import csv
import datetime

# %%
data = pd.read_csv('train.csv', index_col='PassengerId')
kaggle_test = pd.read_csv('test.csv', index_col='PassengerId')
gender_submission = pd.read_csv('gender_submission.csv')

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data = data.replace('male', 0)
data = data.replace('female', 1)
data = data.replace('Q', 0)
data = data.replace('C', 1)
data = data.replace('S', 2)
X = data[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']]
y = data['Survived']
# Out:
# C:\Users\SystemX\AppData\Local\Temp\ipykernel_14720\3913711457.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data = data.replace('female', 1)
# C:\Users\SystemX\AppData\Local\Temp\ipykernel_14720\3913711457.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data = data.replace('S', 2)

# %%
forest = RandomForestClassifier(random_state=3, n_estimators=12, min_samples_leaf=1, max_depth=7, n_jobs=-1)
forest.fit(X, y)
# Out:
# RandomForestClassifier(max_depth=7, n_estimators=12, n_jobs=-1, random_state=3)

# %%
kaggle_test = kaggle_test.replace('male', 0)
kaggle_test = kaggle_test.replace('female', 1)
kaggle_test = kaggle_test.replace('Q', 0)
kaggle_test = kaggle_test.replace('C', 1)
kaggle_test = kaggle_test.replace('S', 2)
X_kaggle_test = kaggle_test[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']]

# %%
kaggle_test['Pclass'] = kaggle_test['Pclass'].fillna(value=kaggle_test['Pclass'].mean())
kaggle_test['Sex'] = kaggle_test['Sex'].fillna(value=kaggle_test['Sex'].mean())
kaggle_test['SibSp'] = kaggle_test['SibSp'].fillna(value=kaggle_test['SibSp'].mean())
kaggle_test['Age'] = kaggle_test['Age'].fillna(value=kaggle_test['Age'].mean())
kaggle_test['Parch'] = kaggle_test['Parch'].fillna(value=kaggle_test['Parch'].mean())
kaggle_test['Fare'] = kaggle_test['Fare'].fillna(value=kaggle_test['Fare'].mean())

# %%
y_predicted_kaggle_test = forest.predict(X_kaggle_test)

# %%
kaggle_test.head()
# Out:
#              Pclass                                          Name  Sex   Age  \
# PassengerId
# 892               3                              Kelly, Mr. James    0  34.5
# 893               3              Wilkes, Mrs. James (Ellen Needs)    1  47.0
# 894               2                     Myles, Mr. Thomas Francis    0  62.0
# 895               3                              Wirz, Mr. Albert    0  27.0
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.0
#
#              SibSp  Parch   Ticket     Fare Cabin  Embarked
# PassengerId
# 892              0      0   330911   7.8292   NaN         0
# 893              1      0   363272   7.0000   NaN         2
# 894              0      0   240276   9.6875   NaN         0
# 895              0      0   315154   8.6625   NaN         2
# 896              1      1  3101298  12.2875   NaN         2

# %%
predictions = y_predicted_kaggle_test.astype(int)
output = pd.DataFrame({'PassengerId': X_kaggle_test.index.to_list(), 'Survived': y_predicted_kaggle_test })
file_name = f'submission_{datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")}.csv'
output.to_csv(file_name, index=False)
